# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://kestra:k3str4@localhost:5432/postgres-zoomcamp')
engine.connect()

# %% [markdown]
# #### 1) Within the execution for `Yellow` Taxi data for the year `2020` and month `12`: what is the uncompressed file size (i.e. the output file `yellow_tripdata_2020-12.csv` of the `extract` task)?

# %% [markdown]
#  ### Choice: 128.3MB
#
#  ![image.png](attachment:e94ac1dd-850d-42b0-8d59-79ea291b44bb.png)

# %% [markdown]
# ### 2) What is the rendered value of the variable `file` when the inputs `taxi` is set to `green`, `year` is set to `2020`, and `month` is set to `04` during execution?
#
# ### Choice: `{{inputs.taxi}}_tripdata_{{inputs.year}}-{{inputs.month}}.csv`

# %% [markdown]
# ### 3) How many rows are there for the `Yellow` Taxi data for all CSV files in the year 2020?

# %%
querry = """
SELECT count(*)
	FROM public.yellow_tripdata 
	where filename in ('yellow_tripdata_2020-01.csv', 'yellow_tripdata_2020-02.csv', 'yellow_tripdata_2020-03.csv', 'yellow_tripdata_2020-04.csv', 'yellow_tripdata_2020-05.csv', 'yellow_tripdata_2020-06.csv', 'yellow_tripdata_2020-07.csv', 'yellow_tripdata_2020-08.csv', 
    'yellow_tripdata_2020-09.csv', 'yellow_tripdata_2020-10.csv', 'yellow_tripdata_2020-11.csv', 'yellow_tripdata_2020-12.csv');
"""

pd.read_sql(querry, con=engine)
# Out:
#       count
# 0  24648499

# %% [markdown]
# ### 4) How many rows are there for the `Green` Taxi data for all CSV files in the year 2020?

# %%
query = """
SELECT count(*)
	FROM public.green_tripdata 
	where filename in ('green_tripdata_2020-01.csv', 'green_tripdata_2020-02.csv', 'green_tripdata_2020-03.csv', 'green_tripdata_2020-04.csv', 'green_tripdata_2020-05.csv', 'green_tripdata_2020-06.csv', 'green_tripdata_2020-07.csv', 'green_tripdata_2020-08.csv', 'green_tripdata_2020-09.csv', 'green_tripdata_2020-10.csv', 'green_tripdata_2020-11.csv', 'green_tripdata_2020-12.csv');
"""

pd.read_sql(query, con=engine)
# Out:
#      count
# 0  1734051

# %% [markdown]
# ### 5) How many rows are there for the `Yellow` Taxi data for the March 2021 CSV file?

# %%
query = """
SELECT count(*)
	FROM public.yellow_tripdata 
	where filename in ('yellow_tripdata_2021-03.csv')
"""

pd.read_sql(query, con=engine)B
# Out:
#      count
# 0  1925152

# %% [markdown]
# ### 6) How would you configure the timezone to New York in a Schedule trigger?
#
# #### Choice: Add a `timezone` property set to `America/New_York` in the `Schedule` trigger configuration
